# %%
# !python --version
# Out:
# Python 3.13.15

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
img = cv2.imread('/content/gdrive/My Drive/ColabIP26/Images/karina.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x840>

# %%
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) #BGR 순서를 RGB 순서로 바꾸라는 뜻
plt.imshow(RGB_img) #plt 라이브러리를 이용한 그림 불러오기
